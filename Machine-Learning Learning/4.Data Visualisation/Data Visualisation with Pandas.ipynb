# %% [markdown]
# # Data Visualisation with Pandas

# %% [raw]
# Nowadays Data scientist and analysts rarely uses Inbuilt python visulisation libraries,matplot and seaborn as it is less interactive and has less beautification when we compare them to new libraries like Bokeh ,Dash(plotly)and d3.js .
# But it is good to know these old methods as well for quickly visualising the raw data.
#
# Key Points :-
#
# 1.Code-wise all visulaisation libraries are almost same ,we don't need to remember all   functions.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt # matlab and matplotlib are different
# %matplotlib inline 
# for showing graph in the notebook (for older versions)

# %%
from numpy.random import randn, randint, uniform, sample
# randn generates n random numbers 
# randn return a sample (or samples) from the “standard normal” distribution

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07 -0.556232
# 2019-06-08 -1.835878
# 2019-06-09  1.139203
# 2019-06-10  1.289893
# 2019-06-11 -0.357631

# %%
ts.plot()#by default it gives line plot

# %%
ts.plot(figsize=(15,5)) # figsize is nothing but size of the graph window

# %% [raw]
# There is a difference between Dashboarding tools like Power BI,Tableau vs Python Visualisation libraries as in day to day life of data scientist we can't use reporting tools for analysing raw data.Power BI etc are good for bussiness analysis and reporting ,but for quickly get the insight of the data, python visualisation libraries are handy.

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07 -0.251494
# 2019-06-08 -1.611236
# 2019-06-09 -1.415826
# 2019-06-10 -1.309582
# 2019-06-11 -2.528197

# %%
ts = ts.cumsum()#cumsum = sum of previous and current element
ts.head()
# Out:
# 2019-06-07    0.303389
# 2019-06-08    0.468993
# 2019-06-09   -0.477371
# 2019-06-10   -1.355549
# 2019-06-11   -1.686377
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(5,5))

# %%
plt.plot(ts)

# %%
df.plot()

# %%
ts.plot(kind="bar",figsize=(50,5))

# %% [markdown]
# ### Iris Dataset

# %%
iris = sns.load_dataset('iris')#sns has inbuilt iris dataset
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
#By only seeing below graph we can give a rough idea of range that in these characteristic lies.
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %% [markdown]
# ### Titanic Dataset

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -1.069118 -0.150049  0.931482  1.593798
# 1  0.549618 -0.192400  0.370348 -0.610051
# 2 -2.929423  1.121234 -1.129604 -0.416023
# 3  0.096282 -0.197836  0.826530 -1.677097
# 4  0.092173 -1.889911  1.638839  0.814022
# 5  1.028500 -0.610841  1.008720 -1.431205
# 6 -0.471398 -1.095630 -0.035994 -0.011468
# 7  0.163476  2.174600 -1.257149 -0.459283
# 8 -0.432451  0.125661 -1.411527  0.381961
# 9 -0.976514 -1.647674 -0.855285  0.732581

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()
#barh 'h' here is for rotating the graph horizontly

# %%
iris.plot.hist()
# A histogram is a plot that lets you discover,
# and show, the underlying frequency distribution (shape) of a set of continuous data.

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)
#bins is the width of the graph line ,the higher is the bins value
#small is the width of the graph.

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x122081550>,
# ...
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)
#s is size of the bubble

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (5,5))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12295f970>,
# ...
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a303d2630>,
# ...
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %% [markdown]
# ### Scatter Matrix

# %%
from pandas.plotting import scatter_matrix
#scatter_matrix = all data matrix comparison with all data

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
df['sepal_length'].plot.kde()

# %%
andrew_curves
#not much used

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)
#logy = first converts into logarithmic form then make a graph

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1248a1040>,
# ...
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
from descartes import PolygonPatch

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()

# %%
import geopandas as gpd

# %%
map_df
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# ...
